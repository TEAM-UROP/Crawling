# %%
import pandas as pd
from gensim.models import Word2Vec
import optuna
from sklearn.model_selection import train_test_split

class Embedding:
    def __init__(self, corpus):
        self.df = pd.read_csv(corpus)
        # 텍스트를 토큰화하여 리스트로 변환
        self.corpus = [
            str(sentence).lower().split()
            for sentence in self.df["comments"]
            if pd.notnull(sentence)
        ]

    # TODO: corpus를 train, test, validation으로 split 하여 임베딩 진행 or 임베딩 진행 후 split -> 나중에 argparser로 선택할 수 있도록 구현
    def get_split_data(self, option):
        if option == 0:
            # 옵션 0: 나누지 않고 전체 코퍼스를 훈련에 사용
            train_corpus = self.corpus
            test_corpus = None
            validation_corpus = None
        else:
            # 옵션 1: 코퍼스를 훈련, 테스트, 검증 세트로 나눔
            train_corpus, temp_corpus = train_test_split(self.corpus, test_size=0.5, random_state=42)
            test_corpus, validation_corpus = train_test_split(temp_corpus, test_size=0.4, random_state=42)
        return train_corpus, test_corpus, validation_corpus

    def objective(self, trial):
        # 하이퍼파라미터 탐색할 범위 지정
        vector_size = trial.suggest_int("vector_size", 10, 100)
        window = trial.suggest_int("window", 3, 10)
        min_count = trial.suggest_int("min_count", 5, 30)
        sg = trial.suggest_categorical("sg", [0])
        # Word2Vec 모델 정의
        model = Word2Vec(
            vector_size=vector_size, window=window, min_count=min_count, sg=sg
        )
        # 모델 학습
        # print(tokenized_corpus)
        model.build_vocab(self.corpus)
        model.train(
            corpus_iterable=self.corpus,
            total_examples=model.corpus_count,
            epochs=model.epochs,
            compute_loss=True,
        )
        # 목적 함수(여기선 단순히 학습 손실값 반환) 설정
        loss = model.get_latest_training_loss()
        return loss

    def get_embedding_vector(self):
        # Optuna를 사용하여 최적화 실행
        study = optuna.create_study(direction="minimize")
        study.optimize(self.objective, n_trials=100)
        # 최적의 하이퍼파라미터 출력
        print("Best parameters:", study.best_params)
        # 최적의 하이퍼파라미터로 모델 재훈련
        best_params = study.best_params
        best_model = Word2Vec(
            vector_size=best_params["vector_size"],
            window=best_params["window"],
            min_count=best_params["min_count"],
            sg=best_params["sg"],
        )
        best_model.build_vocab(self.corpus)
        best_model.train(
            self.corpus,
            total_examples=best_model.corpus_count,
            epochs=best_model.epochs,
        )
        # 튜닝된 Word2Vec 모델에서 단어 벡터 출력
        word_vectors = best_model.wv
        print("형태: ", word_vectors.vectors.shape)
        return word_vectors


if __name__ == "__main__":
    # 임베딩 옵션 설정
    
    embedding_option = 1
    embedding = Embedding("../tokenized_0.csv")
    train_data, test_data, validation_data = embedding.get_split_data(embedding_option)
    word_vectors = embedding.get_embedding_vector()
# Out:
# [I 2023-11-28 20:33:59,147] A new study created in memory with name: no-name-bcffabbb-33ee-4e19-8285-534005ddf841
# [I 2023-11-28 20:33:59,243] Trial 0 finished with value: 65818.015625 and parameters: {'vector_size': 73, 'window': 5, 'min_count': 8, 'sg': 0}. Best is trial 0 with value: 65818.015625.
# [I 2023-11-28 20:33:59,336] Trial 1 finished with value: 81003.75 and parameters: {'vector_size': 37, 'window': 8, 'min_count': 5, 'sg': 0}. Best is trial 0 with value: 65818.015625.
# [I 2023-11-28 20:33:59,401] Trial 2 finished with value: 31747.177734375 and parameters: {'vector_size': 82, 'window': 8, 'min_count': 26, 'sg': 0}. Best is trial 2 with value: 31747.177734375.
# [I 2023-11-28 20:33:59,481] Trial 3 finished with value: 36825.74609375 and parameters: {'vector_size': 89, 'window': 9, 'min_count': 19, 'sg': 0}. Best is trial 2 with value: 31747.177734375.
# [I 2023-11-28 20:33:59,582] Trial 4 finished with value: 28909.48046875 and parameters: {'vector_size': 80, 'window': 9, 'min_count': 29, 'sg': 0}. Best is trial 4 with value: 28909.48046875.
# [I 2023-11-28 20:33:59,713] Trial 5 finished with value: 47878.953125 and parameters: {'vector_size': 97, 'window': 9, 'min_count': 14, 'sg': 0}. Best is trial 4 with value: 28909.48046875.
# [I 2023-11-28 20:33:59,812] Trial 6 finished with value: 59753.2578125 and parameters: {'vector_size': 76, 'window': 5, 'min_count': 10, 'sg': 0}. Best is trial 4 with value: 28909.48046875.
# [I 2023-11-28 20:33:59,877] Trial 7 finished with value: 28729.328125 and parameters: {'vector_size': 66, 'window': 8, 'min_count': 30, 'sg': 0}. Best is trial 7 with value: 28729.328125.
# [I 2023-11-28 20:34:00,010] Trial 8 finished with value: 59977.578125 and parameters: {'vector_size': 87, 'window': 7, 'min_count': 10, 'sg': 0}. Best is trial 7 with value: 28729.328125.
# [I 2023-11-28 20:34:00,072] Trial 9 finished with value: 34224.265625 and parameters: {'vector_size': 80, 'window': 6, 'min_count': 24, 'sg': 0}. Best is trial 7 with value: 28729.328125.
# [I 2023-11-28 20:34:00,153] Trial 10 finished with value: 37550.3203125 and parameters: {'vector_size': 12, 'window': 3, 'min_count': 20, 'sg': 0}. Best is trial 7 with value: 28729.328125.
# [I 2023-11-28 20:34:00,241] Trial 11 finished with value: 28484.724609375 and parameters: {'vector_size': 56, 'window': 10, 'min_count': 30, 'sg': 0}. Best is trial 11 with value: 28484.724609375.
# [I 2023-11-28 20:34:00,325] Trial 12 finished with value: 28102.4140625 and parameters: {'vector_size': 54, 'window': 10, 'min_count': 30, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:00,412] Trial 13 finished with value: 33521.77734375 and parameters: {'vector_size': 51, 'window': 10, 'min_count': 24, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:00,499] Trial 14 finished with value: 29977.78125 and parameters: {'vector_size': 45, 'window': 10, 'min_count': 27, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:00,594] Trial 15 finished with value: 34175.71875 and parameters: {'vector_size': 30, 'window': 10, 'min_count': 22, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:00,680] Trial 16 finished with value: 43574.7578125 and parameters: {'vector_size': 60, 'window': 7, 'min_count': 16, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:00,771] Trial 17 finished with value: 29363.0625 and parameters: {'vector_size': 29, 'window': 3, 'min_count': 30, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:00,863] Trial 18 finished with value: 31947.857421875 and parameters: {'vector_size': 58, 'window': 10, 'min_count': 26, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:00,949] Trial 19 finished with value: 34681.70703125 and parameters: {'vector_size': 46, 'window': 9, 'min_count': 22, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:01,024] Trial 20 finished with value: 30122.017578125 and parameters: {'vector_size': 65, 'window': 6, 'min_count': 28, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:01,108] Trial 21 finished with value: 28685.189453125 and parameters: {'vector_size': 67, 'window': 8, 'min_count': 30, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:01,187] Trial 22 finished with value: 28725.478515625 and parameters: {'vector_size': 70, 'window': 9, 'min_count': 30, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:01,273] Trial 23 finished with value: 32641.859375 and parameters: {'vector_size': 53, 'window': 8, 'min_count': 25, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:01,401] Trial 24 finished with value: 29139.013671875 and parameters: {'vector_size': 42, 'window': 10, 'min_count': 28, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:01,518] Trial 25 finished with value: 36037.3984375 and parameters: {'vector_size': 63, 'window': 7, 'min_count': 22, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:01,594] Trial 26 finished with value: 35350.22265625 and parameters: {'vector_size': 51, 'window': 9, 'min_count': 28, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:01,738] Trial 27 finished with value: 44269.3828125 and parameters: {'vector_size': 34, 'window': 10, 'min_count': 15, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:01,844] Trial 28 finished with value: 33865.25390625 and parameters: {'vector_size': 22, 'window': 8, 'min_count': 24, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:01,938] Trial 29 finished with value: 30219.55078125 and parameters: {'vector_size': 73, 'window': 9, 'min_count': 27, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:02,015] Trial 30 finished with value: 29031.623046875 and parameters: {'vector_size': 57, 'window': 4, 'min_count': 30, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:02,099] Trial 31 finished with value: 34567.12109375 and parameters: {'vector_size': 70, 'window': 9, 'min_count': 30, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:02,188] Trial 32 finished with value: 29581.1328125 and parameters: {'vector_size': 70, 'window': 10, 'min_count': 28, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:02,322] Trial 33 finished with value: 32030.703125 and parameters: {'vector_size': 67, 'window': 8, 'min_count': 26, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:02,434] Trial 34 finished with value: 29095.5234375 and parameters: {'vector_size': 60, 'window': 9, 'min_count': 29, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:02,560] Trial 35 finished with value: 31876.927734375 and parameters: {'vector_size': 75, 'window': 8, 'min_count': 26, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:02,658] Trial 36 finished with value: 29553.203125 and parameters: {'vector_size': 91, 'window': 9, 'min_count': 29, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:02,744] Trial 37 finished with value: 33377.30859375 and parameters: {'vector_size': 43, 'window': 10, 'min_count': 30, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:02,868] Trial 38 finished with value: 72572.1640625 and parameters: {'vector_size': 49, 'window': 8, 'min_count': 6, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:02,993] Trial 39 finished with value: 37809.94140625 and parameters: {'vector_size': 38, 'window': 9, 'min_count': 19, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:03,095] Trial 40 finished with value: 53794.125 and parameters: {'vector_size': 82, 'window': 7, 'min_count': 12, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:03,172] Trial 41 finished with value: 28584.4921875 and parameters: {'vector_size': 64, 'window': 8, 'min_count': 30, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:03,272] Trial 42 finished with value: 28796.49609375 and parameters: {'vector_size': 55, 'window': 9, 'min_count': 29, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:03,387] Trial 43 finished with value: 30965.65625 and parameters: {'vector_size': 62, 'window': 6, 'min_count': 27, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:03,480] Trial 44 finished with value: 29064.21484375 and parameters: {'vector_size': 70, 'window': 8, 'min_count': 29, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:03,610] Trial 45 finished with value: 32511.12890625 and parameters: {'vector_size': 77, 'window': 10, 'min_count': 25, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:03,704] Trial 46 finished with value: 31094.03125 and parameters: {'vector_size': 87, 'window': 7, 'min_count': 27, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:03,781] Trial 47 finished with value: 28265.72265625 and parameters: {'vector_size': 68, 'window': 9, 'min_count': 30, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:03,878] Trial 48 finished with value: 29720.79296875 and parameters: {'vector_size': 56, 'window': 10, 'min_count': 28, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:03,958] Trial 49 finished with value: 33791.97265625 and parameters: {'vector_size': 66, 'window': 8, 'min_count': 23, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:04,053] Trial 50 finished with value: 36156.5078125 and parameters: {'vector_size': 49, 'window': 9, 'min_count': 20, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:04,131] Trial 51 finished with value: 28661.38671875 and parameters: {'vector_size': 69, 'window': 9, 'min_count': 30, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:04,215] Trial 52 finished with value: 28267.69921875 and parameters: {'vector_size': 76, 'window': 10, 'min_count': 30, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:04,323] Trial 53 finished with value: 28899.185546875 and parameters: {'vector_size': 78, 'window': 10, 'min_count': 29, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:04,420] Trial 54 finished with value: 31702.478515625 and parameters: {'vector_size': 83, 'window': 10, 'min_count': 26, 'sg': 0}. Best is trial 12 with value: 28102.4140625.
# [I 2023-11-28 20:34:04,501] Trial 55 finished with value: 27822.6796875 and parameters: {'vector_size': 95, 'window': 10, 'min_count': 30, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:04,596] Trial 56 finished with value: 30506.67578125 and parameters: {'vector_size': 100, 'window': 10, 'min_count': 27, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:04,734] Trial 57 finished with value: 29890.564453125 and parameters: {'vector_size': 94, 'window': 10, 'min_count': 28, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:04,877] Trial 58 finished with value: 32210.421875 and parameters: {'vector_size': 61, 'window': 10, 'min_count': 25, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:04,967] Trial 59 finished with value: 28674.947265625 and parameters: {'vector_size': 88, 'window': 10, 'min_count': 29, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:05,052] Trial 60 finished with value: 28905.76171875 and parameters: {'vector_size': 74, 'window': 9, 'min_count': 29, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:05,132] Trial 61 finished with value: 28360.8359375 and parameters: {'vector_size': 59, 'window': 9, 'min_count': 30, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:05,230] Trial 62 finished with value: 28358.853515625 and parameters: {'vector_size': 54, 'window': 9, 'min_count': 30, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:05,326] Trial 63 finished with value: 29678.63671875 and parameters: {'vector_size': 54, 'window': 10, 'min_count': 28, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:05,417] Trial 64 finished with value: 28846.12109375 and parameters: {'vector_size': 52, 'window': 5, 'min_count': 30, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:05,533] Trial 65 finished with value: 30262.453125 and parameters: {'vector_size': 47, 'window': 9, 'min_count': 27, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:05,640] Trial 66 finished with value: 29173.48046875 and parameters: {'vector_size': 57, 'window': 9, 'min_count': 28, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:05,745] Trial 67 finished with value: 41128.953125 and parameters: {'vector_size': 59, 'window': 10, 'min_count': 17, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:05,871] Trial 68 finished with value: 29112.193359375 and parameters: {'vector_size': 41, 'window': 4, 'min_count': 30, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:05,961] Trial 69 finished with value: 34029.38671875 and parameters: {'vector_size': 94, 'window': 10, 'min_count': 29, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:06,104] Trial 70 finished with value: 50353.375 and parameters: {'vector_size': 50, 'window': 9, 'min_count': 13, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:06,203] Trial 71 finished with value: 28211.20703125 and parameters: {'vector_size': 66, 'window': 9, 'min_count': 30, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:06,352] Trial 72 finished with value: 28513.6484375 and parameters: {'vector_size': 63, 'window': 10, 'min_count': 30, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:06,505] Trial 73 finished with value: 29238.779296875 and parameters: {'vector_size': 73, 'window': 9, 'min_count': 29, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:06,619] Trial 74 finished with value: 29401.11328125 and parameters: {'vector_size': 59, 'window': 10, 'min_count': 28, 'sg': 0}. Best is trial 55 with value: 27822.6796875.
# [I 2023-11-28 20:34:06,761] Trial 75 finished with value: 27026.73046875 and parameters: {'vector_size': 10, 'window': 9, 'min_count': 30, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:06,863] Trial 76 finished with value: 28568.173828125 and parameters: {'vector_size': 10, 'window': 9, 'min_count': 29, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:06,953] Trial 77 finished with value: 30954.80078125 and parameters: {'vector_size': 84, 'window': 9, 'min_count': 27, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:07,054] Trial 78 finished with value: 35715.96484375 and parameters: {'vector_size': 17, 'window': 9, 'min_count': 30, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:07,210] Trial 79 finished with value: 59904.71875 and parameters: {'vector_size': 23, 'window': 9, 'min_count': 9, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:07,310] Trial 80 finished with value: 28562.462890625 and parameters: {'vector_size': 80, 'window': 8, 'min_count': 30, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:07,428] Trial 81 finished with value: 34537.2578125 and parameters: {'vector_size': 32, 'window': 10, 'min_count': 28, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:07,555] Trial 82 finished with value: 28566.3515625 and parameters: {'vector_size': 68, 'window': 9, 'min_count': 29, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:07,682] Trial 83 finished with value: 31612.22265625 and parameters: {'vector_size': 53, 'window': 10, 'min_count': 26, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:07,801] Trial 84 finished with value: 27786.861328125 and parameters: {'vector_size': 26, 'window': 10, 'min_count': 30, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:07,917] Trial 85 finished with value: 32988.58984375 and parameters: {'vector_size': 19, 'window': 9, 'min_count': 30, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:08,010] Trial 86 finished with value: 28901.91015625 and parameters: {'vector_size': 14, 'window': 10, 'min_count': 29, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:08,093] Trial 87 finished with value: 29615.107421875 and parameters: {'vector_size': 27, 'window': 9, 'min_count': 28, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:08,176] Trial 88 finished with value: 27574.169921875 and parameters: {'vector_size': 23, 'window': 10, 'min_count': 30, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:08,263] Trial 89 finished with value: 29284.763671875 and parameters: {'vector_size': 25, 'window': 10, 'min_count': 29, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:08,364] Trial 90 finished with value: 29967.81640625 and parameters: {'vector_size': 38, 'window': 10, 'min_count': 27, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:08,485] Trial 91 finished with value: 27345.328125 and parameters: {'vector_size': 16, 'window': 10, 'min_count': 30, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:08,634] Trial 92 finished with value: 27927.40625 and parameters: {'vector_size': 14, 'window': 10, 'min_count': 30, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:08,745] Trial 93 finished with value: 28693.013671875 and parameters: {'vector_size': 14, 'window': 10, 'min_count': 28, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:08,831] Trial 94 finished with value: 45758.0703125 and parameters: {'vector_size': 19, 'window': 10, 'min_count': 29, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:08,946] Trial 95 finished with value: 32598.955078125 and parameters: {'vector_size': 15, 'window': 10, 'min_count': 30, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:09,038] Trial 96 finished with value: 28049.14453125 and parameters: {'vector_size': 11, 'window': 10, 'min_count': 30, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:09,179] Trial 97 finished with value: 27903.779296875 and parameters: {'vector_size': 10, 'window': 10, 'min_count': 29, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:09,317] Trial 98 finished with value: 78123.3828125 and parameters: {'vector_size': 10, 'window': 10, 'min_count': 5, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# [I 2023-11-28 20:34:09,409] Trial 99 finished with value: 29072.076171875 and parameters: {'vector_size': 12, 'window': 10, 'min_count': 29, 'sg': 0}. Best is trial 75 with value: 27026.73046875.
# Best parameters: {'vector_size': 10, 'window': 9, 'min_count': 30, 'sg': 0}
# 형태:  (130, 10)

# %%
 def objective(self, trial):
        # 하이퍼파라미터 탐색할 범위 지정
        vector_size = trial.suggest_int("vector_size", 10, 100)
        window = trial.suggest_int("window", 3, 10)
        min_count = trial.suggest_int("min_count", 5, 30)
        sg = trial.suggest_categorical("sg", [0])
        # Word2Vec 모델 정의
        model = Word2Vec(
            vector_size=vector_size, window=window, min_count=min_count, sg=sg
        )
        # 모델 학습
        # print(tokenized_corpus)
        model.build_vocab(self.corpus)
        model.train(
            corpus_iterable=self.corpus,
            total_examples=model.corpus_count,
            epochs=model.epochs,
            compute_loss=True,
        )
        # 목적 함수(여기선 단순히 학습 손실값 반환) 설정
        loss = model.get_latest_training_loss()
        return loss

# %%
    def get_embedding_vector(self):
        # Optuna를 사용하여 최적화 실행
        study = optuna.create_study(direction="minimize")
        study.optimize(self.objective, n_trials=100)
        # 최적의 하이퍼파라미터 출력
        print("Best parameters:", study.best_params)
        # 최적의 하이퍼파라미터로 모델 재훈련
        best_params = study.best_params
        best_model = Word2Vec(
            vector_size=best_params["vector_size"],
            window=best_params["window"],
            min_count=best_params["min_count"],
            sg=best_params["sg"],
        )
        best_model.build_vocab(self.corpus)
        best_model.train(
            self.corpus,
            total_examples=best_model.corpus_count,
            epochs=best_model.epochs,
        )
        # 튜닝된 Word2Vec 모델에서 단어 벡터 출력
        word_vectors = best_model.wv
        print("형태: ", word_vectors.vectors.shape)
        return word_vectors


if __name__ == "__main__":
    embedding = Embedding("./tokenized_0.csv")
    word_vectors = embedding.get_embedding_vector()
