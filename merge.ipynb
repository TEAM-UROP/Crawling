# %%
import pandas as pd
import re


csv_file_path = 'D:\\강의\\3-2\\학부연구참여(UROP)\\YongRullNewTown\\Crawling\\첫번째댓글요\\comment_2023-10-29_14-15-34_(1 to 3).csv'

df = pd.read_csv(csv_file_path)

print(df)
# Out:
#                                               comments comments_writer
# 0                     감정이 왜 그렇게 널뛰기를 하는지 이해가 안가는 엔팁입니다          entp러버
# 1    저도요..\n음 그래서 이유를 물어보면 대답을 잘 안해주는데요\n그냥 짜증나거나 예...        ENTJ큐큐QQ
# 2                                           너무 귀엽네요...          33isfj
# 3                   귀엽죠 ㅋㅋ 강아지 같아요\n애기같아서 애기라고 하거든요 ㅎㅎ        ENTJ큐큐QQ
# 4    ㅠㅠ저는 극i라서 맨날 집에 박혀있고 만나는 사람이라곤 일하다가 만난 사람밖에 없어...          33isfj
# ..                                                 ...             ...
# 343                  반대성격에 끌리나요? ex) 이성적,차분함이있는사람들에게요?           라라랜드으
# 344  넵 맞습니다 저는 무조건 조용하고 차분한 사람한테 일단 끌리는데요… 그래서 intj...            하이루미
# 345  인프피가 보낸 그 장문의 톡만큼의 생각을, 엔프피 또한 합니다.\n다만 정리를 잘 ...            Arte
# 346  많이 하는데 저의 경우는 솔직히 계산도 많이 해서 그거에 대한 인정,감사 같은거 못...         샤카 enfp
# 347  ㅋㅎㅎ 넹 생각이 많네요,,\n근데 그걸 하나하나 다 말할 수도 없고, 어느 정도는...            암엥뿌삐
#
# [348 rows x 2 columns]

# %%
mbti_dic = {'엥':'EN','뿌':'F','삐':'P','엔':"EN",'인':'IN','티':'T','제':'J','잇':'IS','엣':'ES'}


ISTJ (Introverted, Sensing, Thinking, Judging)
ISFJ (Introverted, Sensing, Feeling, Judging)
INFJ (Introverted, Intuitive, Feeling, Judging)
INTJ (Introverted, Intuitive, Thinking, Judging)
ISTP (Introverted, Sensing, Thinking, Perceiving)
ISFP (Introverted, Sensing, Feeling, Perceiving)
INFP (Introverted, Intuitive, Feeling, Perceiving)
INTP (Introverted, Intuitive, Thinking, Perceiving)
ESTP (Extraverted, Sensing, Thinking, Perceiving)
ESFP (Extraverted, Sensing, Feeling, Perceiving)
ENFP (Extraverted, Intuitive, Feeling, Perceiving)
ENTP (Extraverted, Intuitive, Thinking, Perceiving)
ESTJ (Extraverted, Sensing, Thinking, Judging)
ESFJ (Extraverted, Sensing, Feeling, Judging)
ENFJ (Extraverted, Intuitive, Feeling, Judging)
ENTJ (

# %%
filtered_eng_mbti = [mbti for mbti in df['comments_writer'] if ['ISTJ', 'ISFJ', 'INFJ', 'INTJ', 'ISTP', 'ISFP', 'INFP', 'INTP',
    'ESTP', 'ESFP', 'ENFP', 'ENTP', 'ESTJ', 'ESFJ', 'ENFJ', 'ENTJ'] in mbti]
filtered_eng_mbti
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\강의\3-2\학부연구참여(UROP)\YongRullNewTown\Crawling\merge.ipynb 셀 3 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/%EA%B0%95%EC%9D%98/3-2/%ED%95%99%EB%B6%80%EC%97%B0%EA%B5%AC%EC%B0%B8%EC%97%AC%28UROP%29/YongRullNewTown/Crawling/merge.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> filtered_eng_mbti = [mbti for mbti in df['comments_writer'] if ['ISTJ', 'ISFJ', 'INFJ', 'INTJ', 'ISTP', 'ISFP', 'INFP', 'INTP',
#       <a href='vscode-notebook-cell:/d%3A/%EA%B0%95%EC%9D%98/3-2/%ED%95%99%EB%B6%80%EC%97%B0%EA%B5%AC%EC%B0%B8%EC%97%AC%28UROP%29/YongRullNewTown/Crawling/merge.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a>     'ESTP', 'ESFP', 'ENFP', 'ENTP', 'ESTJ', 'ESFJ', 'ENFJ', 'ENTJ'] in mbti]
# ...

# %%
# comments_writer 열의 값을 처리하여 MBTI 유형만 남기기
df['comments_writer'] = df['comments_writer'].str.upper()

a = []
b = []

for i in df['comments_writer']:
    mbti_types = re.findall(r'[A-Z]+', i)
    if mbti_types:
        a.append(mbti_types[0])
    else:
        b.append(i)

# 유효한 MBTI 유형 출력
# a 리스트에서 INTP 및 ENFJ 값만 필터링
filtered_eng_mbti = [mbti for mbti in a if mbti in ['ISTJ', 'ISFJ', 'INFJ', 'INTJ', 'ISTP', 'ISFP', 'INFP', 'INTP',
    'ESTP', 'ESFP', 'ENFP', 'ENTP', 'ESTJ', 'ESFJ', 'ENFJ', 'ENTJ']]

# 필터링된 MBTI 유형 출력
print(filtered_eng_mbti)

# MBTI 유형이 아닌 값 출력
print(b)

# 유효한 MBTI 유형의 개수
print(len(filtered_eng_mbti))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\강의\3-2\학부연구참여(UROP)\YongRullNewTown\Crawling\merge.ipynb 셀 4 line 9
#       <a href='vscode-notebook-cell:/d%3A/%EA%B0%95%EC%9D%98/3-2/%ED%95%99%EB%B6%80%EC%97%B0%EA%B5%AC%EC%B0%B8%EC%97%AC%28UROP%29/YongRullNewTown/Crawling/merge.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> for i in df['comments_writer']:
#       <a href='vscode-notebook-cell:/d%3A/%EA%B0%95%EC%9D%98/3-2/%ED%95%99%EB%B6%80%EC%97%B0%EA%B5%AC%EC%B0%B8%EC%97%AC%28UROP%29/YongRullNewTown/Crawling/merge.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a>     mbti_types = re.findall(r'[A-Z]+', i)
# ----> <a href='vscode-notebook-cell:/d%3A/%EA%B0%95%EC%9D%98/3-2/%ED%95%99%EB%B6%80%EC%97%B0%EA%B5%AC%EC%B0%B8%EC%97%AC%28UROP%29/YongRullNewTown/Crawling/merge.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a>     if mbti_types:
# ...

# %%
b
# Out:
# ['겨울이오기전',
#  '겨울이오기전',
#  '용기가 필요한 잇프피',
#  '바다ㅏ',
#  '최고다 인생',
#  '뿡빵뿡',
#  '뿡빵뿡',
#  '뿡빵뿡',
#  '뿡빵뿡',
#  '뿡빵뿡',
#  '뿡빵뿡',
#  '프피가 나라를 구한다',
#  '군고구마균',
#  '인프제는 귀여워',
#  '고양이 3630',
#  '라라랜드으',
#  '사회화된잇티제',
#  '물음표살인마 쁏팁',
#  '암엥뿌삐',
#  '반짝반짝하다',
#  '하이루미',
#  '잇ㅌㅂ',
#  '엔인팁 엔인프피',
#  '즈믄',
#  '라라랜드으',
#  '엔팁 계란말잉',
#  '잇팁같은엣팁',
#  '뿌린',
#  '헬로헬로젤리',
#  '읭프피',
#  '헬로헬로젤리',
#  '인프피 루룰',
#  '엥에엥뿌피',
#  '인프제는 귀여워',
#  '아지야귀여워',
#  '꼬꼬밥',
#  '이귤',
#  '탑하티',
#  '이귤',
#  '탑하티',
#  '나무늘보다',
#  '이잉뿌제',
#  '나는야비타민엥뿌삐',
#  '잇ㅌㅂ',
#  '암엥뿌삐',
#  '엥뿌삐세요',
#  '순두부먹곱',
#  '엔픗피',
#  '엔픗피',
#  '피치티',
#  '리리릿',
#  '꼬꼬밥',
#  '리리릿',
#  '리리릿',
#  '꼬꼬밥',
#  '도라미오',
#  '행복해',
#  '엔픗피',
#  '암엥뿌삐',
#  '뿅망치뿅',
#  '뿡빵뿡',
#  '뿡빵뿡',
#  '안드로메스',
#  '뿡빵뿡',
#  '밤프제',
#  '뿡빵뿡',
#  '뿡빵뿡',
#  '뿅망치뿅',
#  '이이우',
#  '뿅망치뿅',
#  '이이우',
#  '이이우',
#  '이이우',
#  '이이우',
#  '이이우',
#  '하이루미',
#  '키티버니포니',
#  '라라랜드으',
#  '하이루미',
#  '필릴릴리',
#  '그물',
#  '그물',
#  '그물',
#  '그물',
#  '그물',
#  '그물',
#  '하이루미',
#  '하이루미',
#  '하이루미',
# ...

# %%
# mbti_dic에 정의된 대응 관계
mbti_dic = {'엥':'EN', '뿌':'F', '삐':'P', '엔':'EN', '인':'IN',
             '티':'T', '제':'J', '잇':'IS', '엣':'ES', '팁':'TP',
               '프':'F', '푸':'F', '1':'I','2':'E'}

# 변환된 MBTI 유형을 저장할 빈 리스트
converted_mbti = []

# b 리스트의 각 문자열에 대해 처리
for string in b:
    converted_string = ''
    for char in string:
        if char in mbti_dic:
            converted_string += mbti_dic[char]
    if converted_string:
        converted_mbti.append(converted_string)

# a 리스트에서 INTP 및 ENFJ 값만 필터링
filtered_kor_mbti = [mbti for mbti in converted_mbti if mbti in ['ISTJ', 'ISFJ', 'INFJ', 'INTJ', 'ISTP', 'ISFP', 'INFP', 'INTP',
    'ESTP', 'ESFP', 'ENFP', 'ENTP', 'ESTJ', 'ESFJ', 'ENFJ', 'ENTJ']]

# 변환된 MBTI 유형 출력
print(filtered_kor_mbti)
print(len(filtered_kor_mbti))
# Out:
# ['INFJ', 'ISTJ', 'INTP', 'ENFP', 'ENTP', 'INFJ', 'ENFP', 'ENFP', 'ENFP', 'ENFP', 'ENFP']
# 11

# %%
# comments_writer 열의 값을 처리하여 MBTI 유형만 남기기
df['comments_writer'] = df['comments_writer'].str.upper()

a = []
b = []

for i in df['comments_writer']:
    mbti_types = re.findall(r'[A-Z]+', i)
    if mbti_types:
        a.append(mbti_types[0])
    else:
        b.append(i)

# 유효한 MBTI 유형 출력
# a 리스트에서 INTP 및 ENFJ 값만 필터링
filtered_eng_mbti = [mbti for mbti in a if mbti in ['ISTJ', 'ISFJ', 'INFJ', 'INTJ', 'ISTP', 'ISFP', 'INFP', 'INTP',
    'ESTP', 'ESFP', 'ENFP', 'ENTP', 'ESTJ', 'ESFJ', 'ENFJ', 'ENTJ']]

# 필터링된 MBTI 유형 출력
print(filtered_eng_mbti)

# MBTI 유형이 아닌 값 출력
print(b)

# 유효한 MBTI 유형의 개수
print(len(filtered_eng_mbti))
# Out:
# ['ENTP', 'ENTJ', 'ISFJ', 'ENTJ', 'ISFJ', 'ENFJ', 'ENFP', 'INFJ', 'INFJ', 'INFJ', 'ENTP', 'ISFJ', 'INFP', 'INTP', 'INFJ', 'INFP', 'INFP', 'INFP', 'ISTJ', 'INFP', 'ENFP', 'INFP', 'INFP', 'INTP', 'ENTJ', 'ENFP', 'ENFP', 'ISFJ', 'ENFP', 'INTP', 'ENFP', 'INTP', 'ENFP', 'ENFP', 'ESFP', 'INFP', 'ENFP', 'ENTJ', 'ENTJ', 'ENTJ', 'ENFP', 'ENTJ', 'ISTP', 'ENFJ', 'INTP', 'ENFJ', 'INFJ', 'ENFP', 'INFP', 'INFJ', 'ISFJ', 'ISTP', 'ESTP', 'INFP', 'ISTP', 'INFP', 'INFP', 'ESTP', 'ESTP', 'ISTJ', 'ESTP', 'INFJ', 'ENTP', 'ISTP', 'ISTP', 'ISTP', 'ISTP', 'ENFP', 'ENFP', 'ENFP', 'ISTJ', 'ENFP', 'ENFP', 'ENFP', 'INFP', 'INFP', 'ENFP', 'ENTP', 'INTJ', 'INTJ', 'ISTP', 'ISTP', 'INFJ', 'ENFP', 'ENFP', 'ENFJ', 'ENFP', 'ENFJ', 'ENFP', 'ENFJ', 'ENFP', 'ENFJ', 'ENFJ', 'ENFP', 'ENFJ', 'ENFP', 'INFP', 'INFP', 'INFP', 'INTJ', 'INTJ', 'INTJ', 'INTJ', 'ENFJ', 'INTJ', 'ENFJ', 'ENTP', 'INFP', 'ENFJ', 'INFP', 'INFP', 'ENFJ', 'ISTP', 'INFP', 'INFP', 'ISTP', 'INFP', 'ISTP', 'ISTP', 'INFJ', 'INFJ', 'ENFP', 'INFJ', 'INFJ', 'INFJ
# ...

# %%
# mbti_dic에 정의된 대응 관계
mbti_dic = {'엥':'EN', '뿌':'F', '삐':'P', '엔':'EN', '인':'IN',
             '티':'T', '제':'J', '잇':'IS', '엣':'ES', '팁':'TP',
               '프':'F', '푸':'F', '1':'I','2':'E'}

# 변환된 MBTI 유형을 저장할 빈 리스트
converted_mbti = []

# b 리스트의 각 문자열에 대해 처리
for string in b:
    converted_string = ''
    for char in string:
        if char in mbti_dic:
            converted_string += mbti_dic[char]
    if converted_string:
        converted_mbti.append(converted_string)

# a 리스트에서 INTP 및 ENFJ 값만 필터링
filtered_kor_mbti = [mbti for mbti in converted_mbti if mbti in ['ISTJ', 'ISFJ', 'INFJ', 'INTJ', 'ISTP', 'ISFP', 'INFP', 'INTP',
    'ESTP', 'ESFP', 'ENFP', 'ENTP', 'ESTJ', 'ESFJ', 'ENFJ', 'ENTJ']]

# 변환된 MBTI 유형 출력
print(filtered_kor_mbti)
print(len(filtered_kor_mbti))
# Out:
# ['INFJ', 'ISTJ', 'INTP', 'ENFP', 'ENTP', 'INFJ', 'ENFP', 'ENFP', 'ENFP', 'ENFP', 'ENFP']
# 11

# %%
import pandas as pd
import re


mbti_dic = {'엥':'EN', '뿌':'F', '삐':'P', '엔':'EN', '인':'IN',
             '티':'T', '제':'J', '잇':'IS', '엣':'ES', '팁':'TP',
               '프':'F', '푸':'F', '1':'I','2':'E'}
csv_file_path = 'D:\\강의\\3-2\\학부연구참여(UROP)\\YongRullNewTown\\Crawling\\첫번째댓글요\\comment_2023-10-29_14-15-34_(1 to 3).csv'
df = pd.read_csv(csv_file_path)

author = df['comments_writer'].str.upper()

for idx, row in enumerate(author):
    # 영어 먼저 라벨링
    mbti_types = re.findall(r'[A-Z]+', row)
    if mbti_types:
        author[idx] = mbti_types[0]
    # 그다음 한글 라벨링
    else:
        converted_string = ''
        for char in row:
            if char in mbti_dic:
                converted_string += mbti_dic[char]
        if converted_string:
            author[idx] = converted_string
        else:
            df = df.drop(idx)
filtered_kor_mbti = [mbti for mbti in converted_mbti if mbti in ['ISTJ', 'ISFJ', 'INFJ', 'INTJ', 'ISTP', 'ISFP', 'INFP', 'INTP',
    'ESTP', 'ESFP', 'ENFP', 'ENTP', 'ESTJ', 'ESFJ', 'ENFJ', 'ENTJ']]


df
# Out:
#                                               comments comments_writer
# 0                     감정이 왜 그렇게 널뛰기를 하는지 이해가 안가는 엔팁입니다          entp러버
# 1    저도요..\n음 그래서 이유를 물어보면 대답을 잘 안해주는데요\n그냥 짜증나거나 예...        ENTJ큐큐QQ
# 2                                           너무 귀엽네요...          33isfj
# 3                   귀엽죠 ㅋㅋ 강아지 같아요\n애기같아서 애기라고 하거든요 ㅎㅎ        ENTJ큐큐QQ
# 4    ㅠㅠ저는 극i라서 맨날 집에 박혀있고 만나는 사람이라곤 일하다가 만난 사람밖에 없어...          33isfj
# ..                                                 ...             ...
# 339  사람 좋아하는 엔프피는 상대방(이성)에게 나도 너랑 정들었다 이런 표현 빈말로도 할...       Iris istj
# 341                                  일주일 약속 평균 몇 번이세요?        intp 삼다수
# 345  인프피가 보낸 그 장문의 톡만큼의 생각을, 엔프피 또한 합니다.\n다만 정리를 잘 ...            Arte
# 346  많이 하는데 저의 경우는 솔직히 계산도 많이 해서 그거에 대한 인정,감사 같은거 못...         샤카 enfp
# 347  ㅋㅎㅎ 넹 생각이 많네요,,\n근데 그걸 하나하나 다 말할 수도 없고, 어느 정도는...            암엥뿌삐
#
# [280 rows x 2 columns]

# %%
import pandas as pd
import re


mbti_dic = {'엥':'EN', '뿌':'F', '삐':'P', '엔':'EN', '인':'IN',
             '티':'T', '제':'J', '잇':'IS', '엣':'ES', '팁':'TP',
               '프':'F', '푸':'F', '1':'I','2':'E'}
csv_file_path = 'D:\\강의\\3-2\\학부연구참여(UROP)\\YongRullNewTown\\Crawling\\첫번째댓글요\\comment_2023-10-29_14-15-34_(1 to 3).csv'
df = pd.read_csv(csv_file_path)

author = df['comments_writer'].str.upper()

for idx, row in enumerate(author):
    # 영어 먼저 라벨링
    mbti_types = re.findall(r'[A-Z]+', row)
    if mbti_types:
        author[idx] = mbti_types[0]
    # 그다음 한글 라벨링
    else:
        converted_string = ''
        for char in row:
            if char in mbti_dic:
                converted_string += mbti_dic[char]
        if converted_string:
            author[idx] = converted_string
        else:
            df = df.drop(idx)
df
# Out:
#                                               comments comments_writer
# 0                     감정이 왜 그렇게 널뛰기를 하는지 이해가 안가는 엔팁입니다          entp러버
# 1    저도요..\n음 그래서 이유를 물어보면 대답을 잘 안해주는데요\n그냥 짜증나거나 예...        ENTJ큐큐QQ
# 2                                           너무 귀엽네요...          33isfj
# 3                   귀엽죠 ㅋㅋ 강아지 같아요\n애기같아서 애기라고 하거든요 ㅎㅎ        ENTJ큐큐QQ
# 4    ㅠㅠ저는 극i라서 맨날 집에 박혀있고 만나는 사람이라곤 일하다가 만난 사람밖에 없어...          33isfj
# ..                                                 ...             ...
# 339  사람 좋아하는 엔프피는 상대방(이성)에게 나도 너랑 정들었다 이런 표현 빈말로도 할...       Iris istj
# 341                                  일주일 약속 평균 몇 번이세요?        intp 삼다수
# 345  인프피가 보낸 그 장문의 톡만큼의 생각을, 엔프피 또한 합니다.\n다만 정리를 잘 ...            Arte
# 346  많이 하는데 저의 경우는 솔직히 계산도 많이 해서 그거에 대한 인정,감사 같은거 못...         샤카 enfp
# 347  ㅋㅎㅎ 넹 생각이 많네요,,\n근데 그걸 하나하나 다 말할 수도 없고, 어느 정도는...            암엥뿌삐
#
# [280 rows x 2 columns]

# %%
import pandas as pd
import re

mbti_dic = {
    '엥': 'EN', '뿌': 'F', '삐': 'P', '엔': 'EN', '인': 'IN',
    '티': 'T', '제': 'J', '잇': 'IS', '엣': 'ES', '팁': 'TP',
    '프': 'F', '푸': 'F', '1': 'I', '2': 'E'
}

csv_file_path = 'D:\\강의\\3-2\\학부연구참여(UROP)\\YongRullNewTown\\Crawling\\첫번째댓글요\\comment_2023-10-29_14-15-34_(1 to 3).csv'
df = pd.read_csv(csv_file_path)

def mbti_conversion(row):
    # 영어 MBTI로 변환 가능한 경우
    mbti_types = re.findall(r'[A-Z]+', row)
    if mbti_types:
        return mbti_types[0]
    
    # 한글 MBTI로 변환
    converted_string = ''
    for char in row:
        if char in mbti_dic:
            converted_string += mbti_dic[char]
    
    return converted_string

# 'comments_writer' 열을 복사하여 'mbti' 열을 생성
df['mbti'] = df['comments_writer'].apply(mbti_conversion)

# 필요한 MBTI 유형에 해당하는 행만 추출
valid_mbti = ['ISTJ', 'ISFJ', 'INFJ', 'INTJ', 'ISTP', 'ISFP', 'INFP', 'INTP',
              'ESTP', 'ESFP', 'ENFP', 'ENTP', 'ESTJ', 'ESFJ', 'ENFJ', 'ENTJ']
filtered_df = df[df['mbti'].isin(valid_mbti)]

# 결과를 출력
print(filtered_df)
print(len(filtered_df))
# Out:
#                                               comments comments_writer  mbti
# 1    저도요..\n음 그래서 이유를 물어보면 대답을 잘 안해주는데요\n그냥 짜증나거나 예...        ENTJ큐큐QQ  ENTJ
# 3                   귀엽죠 ㅋㅋ 강아지 같아요\n애기같아서 애기라고 하거든요 ㅎㅎ        ENTJ큐큐QQ  ENTJ
# 9                          엔프피는 그나마 다 잘 맞는 유형 아닐까 싶네요!    딸림음 INFJ 7w6  INFJ
# 10                          N이 수학을 싫어하나요? 전 영수 좋아했는데..     iINFJ A 4w5  INFJ
# 11                                     저도 수학 좋아하는데....    딸림음 INFJ 7w6  INFJ
# ..                                                 ...             ...   ...
# 321                                   "너는 지금언제야" 는 어때요     된장속강아지 INTJ  INTJ
# 324                                 이래서 엥뿌삐를 못끊어요 (어?)     된장속강아지 INTJ  INTJ
# 335                       창을 열어 소리쳐봐라고 한다면 무슨 말을 할건가요?        열일하는ENTP  ENTP
# 337                           아빠는 왜 소외시키나요 창 한번 더 열여야죠        열일하는ENTP  ENTP
# 347  ㅋㅎㅎ 넹 생각이 많네요,,\n근데 그걸 하나하나 다 말할 수도 없고, 어느 정도는...            암엥뿌삐  ENFP
#
# [124 rows x 3 columns]
# 124
